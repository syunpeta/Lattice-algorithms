# %%
using LinearAlgebra

function GSO(B::Matrix{Int64}, N::Int64)::Tuple{Matrix{Float64},Matrix{Float64}}
    B_p = zeros(Float64,size(B))
    mu = zeros(Float64,(N,N))
    for i in 1:N
        B_p[i,:] = B[i,:]
        mu[i,i] = 1
        for j in 1:i-1
            mu[i,j] = B[i,:]⋅B_p[j,:]/norm(B_p[j,:])^2
            B_p[i,:] -= mu[i,j]*B_p[j,:]
        end
    end
    return B_p,mu
end

function return_r(k::Int64,r0::Int64,r::Array{Int64})
    if k == 0
        return r0
    else
        return r[k]
    end
end
        
function ENUM(B::Matrix{Int64})
    N,_ = size(B)
    B_p,mu =GSO(B,N) 
    norm_Bp = zeros(Float64,N)
    for i in 1:N
        norm_Bp[i] = norm(B_p[i,:])^2
    end
    R =zeros(Float64,N)
    R[N] = 0.99*norm(B[1,:])^2
    for i in 1:(N-1)
        #R[i] = (i/N)*R[N]
        R[i] = R[N]
    end
    println(R)
    sigma = zeros(Float64,(N+1,N))
    r = [i for i in 1:N]
    r0 = 0
    rho = zeros(Float64,N+1)
    v = zeros(Int64,N)
    v[1] = 1
    c = zeros(Float64,N)
    w = zeros(Int64,N)
    last_nonzero = 1
    k = 1
    while true
        #print(k)
        rho[k] = rho[k+1] + ((v[k] - c[k])^2) * norm_Bp[k]
        if rho[k] <= R[N+1-k]
            if k == 1
                return v
            else
                k-=1
                ##r
                if k== 1
                    r0 = max(r0,r[k])
                else
                    r[k-1] = max(r[k-1],r[k])
                end
                ##
                for i in return_r(k,r0,r):-1:(k+1)
                    sigma[i,k] = sigma[i+1,k] + v[i]*mu[i,k] 
                end
                c[k] = -sigma[k+1,k]
                print(c[k])
                v[k] = round(c[k])
                w[k] = 1
            end
        else
            k+=1
            if k == (N+1)
                return false
            end
            ##r
            if k==1
                r0 = 1
            else
                r[k-1] = k
            end
            ##
            if k >= last_nonzero
                last_nonzero = k
                v[k]+=1
            else
                if v[k] > c[k]
                    v[k] -= w[k]
                else
                    v[k] += w[k]
                end
                w[k] += 1
            end
        end
    end
end

                
            
BB = [63 -14 -1 84 61;74 -20 23 -32 -52;93 -46 -19 0 -63;93 11 13 60 52;33 -93 12 57 -2]
#=
BB = [-79 35 31 83 -66 35 -32 46 21 2
    43 -64 -37 -31 -27 -7 -42 21 16 16
    -1 -97 -91 -43 19 -21 -65 -36 34 -55
    -58 -38 87 42 94 -83 66 -69 -2 -30
    84 -61 93 -67 3 94 31 27 -60 98
    -1 34 58 -38 29 67 -18 15 -75 -16
    19 16 52 32 -20 55 94 -34 4 80
    -58 -17 99 93 -49 -53 24 51 5 93
    17 31 78 53 40 -22 -39 7 70 -98
    93 -6 -7 -12 79 -40 27 -95 98 20
]=#
ENUM(BB)
# Out:
# [14793.570000000002, 14793.570000000002, 14793.570000000002, 14793.570000000002, 14793.570000000002]
# 0.06297262932476744
# 5-element Vector{Int64}:
#  0
#  1
#  0
#  0
#  0

# %%
function ENUM(B::Matrix{Int64},R::Float64)
    N,_ = size(B)
    B_p,mu =GSO(B,N) 
    norm_Bp = zeros(Float64,N)
    for i in 1:N
        norm_Bp[i] = norm(B_p[i,:])^2
    end
   
    sigma = zeros(Float64,(N+1,N))
    r = [i for i in 0:N]
    rho = zeros(Float64,N+1)
    v = zeros(Int64,N);v[1] = 1
    c = zeros(Float64,N)
    w = zeros(Int64,N)
    last_nonzero = 1
    k = 1
    while true
        rho[k] = rho[k+1] + ((v[k] - c[k])^2) * norm_Bp[k]
        print((rho[k],R,k))
        if rho[k] <= R
            if k == 1
                return v
            else
                k-=1
                r[k] = max(r[k],r[k+1])
                for i in r[k+1]:-1:k+2
                    sigma[i,k] = sigma[i+1,k] + mu[i,k]*v[i] ###????
                end
                c[k] = -sigma[k+1,k]
                v[k] = round(c[k])
                w[k] = 1
            end
        else
            k+=1
            if k == (N+1)
                return false
            end
            r[k] = k+1####?
            if k >= last_nonzero
                last_nonzero = k
                v[k]+=1
            else
                if v[k] > c[k]
                    v[k] -= w[k]
                else
                    v[k] += w[k]
                end
                w[k] += 1
            end
        end
    end
    return v
end
